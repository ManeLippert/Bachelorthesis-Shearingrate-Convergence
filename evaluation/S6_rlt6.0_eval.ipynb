# %% [markdown]
# # (S6) rlt = 6.0

# %%
# Import modules
import zonalflow
import gkw
import derivative
import plot
import h5py
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
from matplotlib.transforms import Bbox

# %%
# Plot parameter
# %matplotlib inline
plot.parameters(True, 22, (24,8), 100)

# %% [markdown]
# ## ```N_s_grid = 16```

# %% [markdown]
# ### ```N_mu_grid = 9```

# %% [markdown]
# #### ```N_vpar_grid = 64```

# %%
# File import
data = 'S6_rlt6.0'
resolution = 'Nsgrid16_Nvpargrid64_Nmugrid9'
rlt = data.split("rlt",1)[1]
filename = '../data/'+data+'/'+resolution+'/gkwdata.h5'
f = h5py.File(filename,"r+")

# %%
# Heat flux
eflux_data, time = zonalflow.get_eflux_time(f)

plot.eflux_time(time, eflux_data, (24,8), data, resolution)

# %%
# Finite Difference for shearing rate omega_ExB
wexb, rad_coord, rad_boxsize, ddphi, dx, zonal_pot = zonalflow.get_shearingrate_radialcoordinate_radialboxsize_ddphi_dx_zonalpot(f)

print('rad_boxsize :', rad_boxsize, '; stepsize :',dx)
# Out:
# rad_boxsize : 76.27048929506829 ; stepsize : 0.595863197617721

# %%
# Fourier plot of time domain

wexb_max = zonalflow.get_max_shearingrate(wexb, time)

plot.max_shearingrate_time(time, wexb_max, (24,8), data, resolution)

# %%
# Plot all shearing rate with mean overe intervall in 1000 steps
plot.all_shearingrate_radialcoordinate(rad_coord, wexb, (12,8), rlt, data, resolution)

# %%
# Plot from 500:2000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (5000)
start, end = 500, 2000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.09652888491123954

# %%
# Plot from 4000:6000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (5000)
start, end = 4000, 6000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.240602129328215

# %%
# Plot from 7000:10000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (8500)
start, end = 7000, 10000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.22470381885762244

# %% [markdown]
# #### ```N_vpar_grid = 48```

# %%
# File import
data = 'S6_rlt6.0'
resolution = 'Nsgrid16_Nvpargrid48_Nmugrid9'
rlt = data.split("rlt",1)[1]
filename = '../data/'+data+'/'+resolution+'/gkwdata.h5'
f = h5py.File(filename,"r+")

# %%
# Heat flux
eflux_data, time = zonalflow.get_eflux_time(f)

plot.eflux_time(time, eflux_data, (24,8), data, resolution)

# %%
# Finite Difference for shearing rate omega_ExB
wexb, rad_coord, rad_boxsize, ddphi, dx, zonal_pot = zonalflow.get_shearingrate_radialcoordinate_radialboxsize_ddphi_dx_zonalpot(f)

print('rad_boxsize :', rad_boxsize, '; stepsize :',dx)
# Out:
# rad_boxsize : 76.27048929506829 ; stepsize : 0.595863197617721

# %%
# Fourier plot of time domain

wexb_max = zonalflow.get_max_shearingrate(wexb, time)

plot.max_shearingrate_time(time, wexb_max, (24,8), data, resolution)

# %%
# Plot all shearing rate with mean overe intervall in 1000 steps
plot.all_shearingrate_radialcoordinate(rad_coord, wexb, (12,8), rlt, data, resolution)

# %%
# Plot from 500:2000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (5000)
start, end = 500, 2000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.2324180347029204

# %%
# Plot from 4000:6000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (5000)
start, end = 4000, 6000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.20994309055728044

# %%
# Plot from 7000:10000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (8500)
start, end = 7000, 10000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.21043887081161491

# %% [markdown]
# #### ```N_vpar_grid = 32```

# %%
# File import
data = 'S6_rlt6.0'
resolution = 'Nsgrid16_Nvpargrid32_Nmugrid9'
rlt = data.split("rlt",1)[1]
filename = '../data/'+data+'/'+resolution+'/gkwdata.h5'
f = h5py.File(filename,"r+")

# %%
# Heat flux
eflux_data, time = zonalflow.get_eflux_time(f)

plot.eflux_time(time, eflux_data, (24,8), data, resolution)

# %%
# Finite Difference for shearing rate omega_ExB
wexb, rad_coord, rad_boxsize, ddphi, dx, zonal_pot = zonalflow.get_shearingrate_radialcoordinate_radialboxsize_ddphi_dx_zonalpot(f)

print('rad_boxsize :', rad_boxsize, '; stepsize :',dx)
# Out:
# rad_boxsize : 76.27048929506829 ; stepsize : 0.595863197617721

# %%
# Fourier plot of time domain

wexb_max = zonalflow.get_max_shearingrate(wexb, time)

plot.max_shearingrate_time(time, wexb_max, (24,8), data, resolution)

# %% [markdown]
# ####  ```N_vpar_grid = 16```

# %%
# File import
data = 'S6_rlt6.0'
resolution = 'Nsgrid16_Nvpargrid16_Nmugrid9'
rlt = data.split("rlt",1)[1]
filename = '../data/'+data+'/'+resolution+'/gkwdata.h5'
f = h5py.File(filename,"r+")

# %%
# Heat flux
eflux_data, time = zonalflow.get_eflux_time(f)

plot.eflux_time(time, eflux_data, (24,8), data, resolution)

# %%
# Finite Difference for shearing rate omega_ExB
wexb, rad_coord, rad_boxsize, ddphi, dx, zonal_pot = zonalflow.get_shearingrate_radialcoordinate_radialboxsize_ddphi_dx_zonalpot(f)

print('rad_boxsize :', rad_boxsize, '; stepsize :',dx)
# Out:
# rad_boxsize : 76.27048929506829 ; stepsize : 0.595863197617721

# %%
# Fourier plot of time domain

wexb_max = zonalflow.get_max_shearingrate(wexb, time)

plot.max_shearingrate_time(time, wexb_max, (24,8), data, resolution)

# %% [markdown]
# ### ```N_mu_grid = 6```

# %% [markdown]
# #### ```N_vpar_grid = 64```

# %%
# File import
data = 'S6_rlt6.0'
resolution = 'Nsgrid16_Nvpargrid64_Nmugrid6'
rlt = data.split("rlt",1)[1]
filename = '../data/'+data+'/'+resolution+'/gkwdata.h5'
f = h5py.File(filename,"r+")

# %%
# Heat flux
eflux_data, time = zonalflow.get_eflux_time(f)

plot.eflux_time(time, eflux_data, (24,8), data, resolution)

# %%
# Finite Difference for shearing rate omega_ExB
wexb, rad_coord, rad_boxsize, ddphi, dx, zonal_pot = zonalflow.get_shearingrate_radialcoordinate_radialboxsize_ddphi_dx_zonalpot(f)

print('rad_boxsize :', rad_boxsize, '; stepsize :',dx)
# Out:
# rad_boxsize : 76.27048929506829 ; stepsize : 0.595863197617721

# %%
# Fourier plot of time domain

wexb_max = zonalflow.get_max_shearingrate(wexb, time)

plot.max_shearingrate_time(time, wexb_max, (24,8), data, resolution)

# %%
# Plot all shearing rate with mean overe intervall in 1000 steps
plot.all_shearingrate_radialcoordinate(rad_coord, wexb, (12,8), rlt, data, resolution)

# %%
# Plot from 500:2000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (5000)
start, end = 500, 2000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.19738413816814795

# %%
# Plot from 4000:6000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (5000)
start, end = 4000, 6000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.2586596597750772

# %%
# Plot from 7000:10000 timesteps with mean over that interval
# Plot of a signal in the middle of the time interval (5000)
start, end = 7000, 10000

# Shearing rate with mean over time
wexb_rad_mean, wexb_rad_middle = zonalflow.get_mean_middle_shearingrate(start, end, wexb)

# FT{shearing rate}
wexb_rad_mean_amp, wexb_rad_mean_amp_max = zonalflow.get_fft_mean_max_shearingrate_amplitude(wexb_rad_mean)

print('Maximal Amplitude: ', wexb_rad_mean_amp_max)

plot.mean_shearingrate_radialcoordinate_amplitude(rad_coord, wexb_rad_mean, wexb_rad_middle, wexb_rad_mean_amp, wexb_rad_mean_amp_max, 
                                                  (24,8), start, end, rlt, data, resolution)
# Out:
# Maximal Amplitude:  0.22537938856030035

# %% [markdown]
# #### ```N_vpar_grid = 48```

# %%
# File import
data = 'S6_rlt6.0'
resolution = 'Nsgrid16_Nvpargrid48_Nmugrid6'
rlt = data.split("rlt",1)[1]
filename = '../data/'+data+'/'+resolution+'/gkwdata.h5'
f = h5py.File(filename,"r+")

# %%
# Heat flux
eflux_data, time = zonalflow.get_eflux_time(f)

plot.eflux_time(time, eflux_data, (24,8), data, resolution)
